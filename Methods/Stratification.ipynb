# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("wages.csv")
data
# Out:
#      Hwage  Educ  Exper  Female  Union
# 0     9.00    10     27       0      0
# 1     5.50    12     20       0      0
# 2     3.80    12      4       1      0
# 3    10.50    12     29       1      0
# 4    15.00    12     40       0      1
# ..     ...   ...    ...     ...    ...
# 522   8.63    12     18       1      0
# 523  18.50    14     13       1      0
# 524  22.20    18      8       0      0
# 525  16.26    12     14       0      1
# 526  19.47    12      9       0      0
#
# [527 rows x 5 columns]

# %%
data[data["Female"]==1]
# Out:
#      Hwage  Educ  Exper  Female  Union
# 2     3.80    12      4       1      0
# 3    10.50    12     29       1      0
# 5     9.00    16     27       1      0
# 6     9.57    12      5       1      1
# 9     5.00    12     14       1      0
# ..     ...   ...    ...     ...    ...
# 518   8.00    12     19       1      0
# 520   5.35    12     13       1      0
# 521  23.25    17     25       1      1
# 522   8.63    12     18       1      0
# 523  18.50    14     13       1      0
#
# [243 rows x 5 columns]

# %%
sns.countplot(x="Female",data=data)

# %%
pivot = pd.pivot_table(data , index=["Female","Union"])
pivot
# Out:
#                    Educ      Exper      Hwage
# Female Union
# 0      0      13.305556  15.328704   9.671898
#        1      12.661765  20.573529  11.288971
# 1      0      12.953488  18.613953   7.473721
#        1      13.428571  21.821429   9.606071
